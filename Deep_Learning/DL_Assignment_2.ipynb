# %% [markdown]
# **Assignment # 2, CNN over Fasion MNIST**
#
# ID #1 : 0008003254 <br>
# ID #2 : 311149082 <br>
#
# In this assignment you are requested to build a convolutional network and train it over the Fasion MNIST data, which is a collection of 28X28 back and white images, classified into 10 different classes of clothing items. For more information about Fashion MNIST you may refer to:
# https://github.com/zalandoresearch/fashion-mnist

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
sns.set_theme(color_codes=True)
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import time

# %%
# Loading Fashion MNIST
def load_Fashion_Data():
  trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                          download=True, transform=transforms.ToTensor())

  testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                        download=True, transform=transforms.ToTensor())
  # Use dataloaders for train and test (batch size is 4)
  trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                            shuffle=True)

  testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                          shuffle=False)

  classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress',
            'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot')
  return trainset, testset, trainloader, testloader

# %%
def load_cifar10_data():
  transform = transforms.Compose([torchvision.transforms.Grayscale(num_output_channels=1),transforms.ToTensor(), transforms.RandomResizedCrop(28)])

  train_data = torchvision.datasets.CIFAR10(root='./data',
                                    train=True,
                                    download=True,
                                    transform=transform)

  test_data = torchvision.datasets.CIFAR10(root='./data',
                                    train=True,
                                    download=True,
                                    transform=transform)
  
  for i in range(9):
    train_data = train_data + torchvision.datasets.CIFAR10(root='./data',
                                    train=True,
                                    download=True,
                                    transform=transform)


  trainloader = torch.utils.data.DataLoader(train_data,
                                            batch_size=4,
                                            shuffle=True)

  testloader = torch.utils.data.DataLoader(test_data, batch_size=4,
                                          shuffle=False)
  return train_data, test_data, trainloader, testloader

# %%
trainset, testset,trainloader,testloader = load_Fashion_Data()
# The images are of 1, 28, 28 size (only one black-white channel)
trainset[0][0].shape
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
# Processing...
# Done!
# torch.Size([1, 28, 28])

# %%
# Plotting the sample images
fig, axes = plt.subplots(3, 3, figsize=(12,12))
for i in range(3):
  for j in range(3):
    # plot raw pixel data
    axes[i][j].imshow(trainset[(3*i)+j%3][0][0])
plt.show()

# %% [markdown]
# # **Part 1**: Implementing a CNN network for Fashion MNIST
# Here is what you need to do; you are encoureged to look at notebook "DL Notebook 9 - CIFAR CNN" when trying to complete the next steps.
#
#
# Write a network CNNFMnist, that has the following architecture:
#
# * Convolution with 10 3X3 filters
# * Relu
# * Max pool with 2X2
# * Convolution with 5 3X3 filters
# * Relu
# * Convolution with 16 3X3 filters
# * Relu
# * Max pool with 2X2
# * Liner, output size 128
# * Relu
# * Liner, output size 64
# * Relu
# * Liner, output size 10

# %%
class CNNFMnist(nn.Module):

    def __init__(self):
        super(CNNFMnist, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, 3) # 10 chanels of 26*26
        #max pooling create 13*13
        self.conv2 = nn.Conv2d(10, 5, 3) # 5 chanels of 11*11
        self.conv3 = nn.Conv2d(5, 16, 3) # 16 chanels of 9*9
        #max pooling create 4*4
        self.fc1 = nn.Linear(16 * 4 * 4, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(F.relu(self.conv3(x)), (2, 2))
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return 0, x

# %% [markdown]
# Write a code that trains the network with FashionMNIST train dataset, for classification (use cross entropy, and SGD).
# Run the network for at least 10 epochs, over the entire dataset. Make sure to print the loss over the train set as well as the **test set** over time (say, every 1000 batches, but it's up to you), so you will know where you are during training.
#
# Note, measuring loss of test is similar to measuring loss over the train test. However, make sure not to run the test images in back propagation. Use them only in forward and calulate the average loss over the entire test set. Since it will make the training process run slower, you should measure loss for the test set only at the end of an epoch (so overall you get 10 loss values for the test set). You are encoureged to write a different function for claculating the loss of the test set, and then call it from the training procedure.
#
#
# You should collect the loss values in an array, so you can plot then into two curves, one for train and one for test.
#
# In addition, you should measure the time it takes you to train the network completely.

# %%
net = CNNFMnist()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
print(net)
# Out:
# CNNFMnist(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 5, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(5, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
def train_and_test_nn(epoch_number, show_loss_round, GPU=False, is_transfered=False):
  train_loss = []
  test_loss = []
  for epoch in range(epoch_number):
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
      # get the inputs
      inputs, labels = data
      if GPU:
        inputs = inputs.cuda() # -- For GPU
        labels = labels.cuda() # -- For GPU

      # zero the parameter gradients
      optimizer.zero_grad()

      # forward + backward + optimize
      hiden, outputs = net(inputs)
      if is_transfered:
        loss = criterion(hiden, labels)
      else:
         loss = criterion(outputs, labels) 
      loss.backward()
      optimizer.step()
      # print statistics
      running_loss += loss.item()  
      
      if (i+1) % show_loss_round == 0:    
        train_loss.append(( ((epoch*15000)+i+1), running_loss/ show_loss_round))
        print('[%d, %5d] loss: %.3f' %
                (epoch + 1, i + 1, running_loss / show_loss_round))
        running_loss = 0.0

    with torch.no_grad():
      running_loss = 0
      for images, labels in testloader:
          if GPU:
            labels = labels.cuda()
          h, outputs = net(inputs)
          # get the inputs
          loss = criterion(outputs, labels)
          running_loss += loss.item()
    
      running_loss /= (testloader.dataset.data.shape[0] / testloader.batch_size)
      test_loss.append(running_loss)

  
  print("Finished training, look below for time:")
  return train_loss, test_loss

# %%
def plot_loss(train_loss, test_loss, time, epoch_num):
  x_train_loss, y_train_loss = list(zip(*train_loss))
  x_test_loss, y_test_loss = test_loss  , np.arange(0,10) 
  # Plot both losses 
  fig, axes = plt.subplots(3, 1, figsize=(45.0, 18.0))
  sns.lineplot(x_train_loss,y_train_loss, ax=axes[0], label="Train Loss", color="blue")
  sns.lineplot(y_test_loss,x_test_loss, ax=axes[1], label="Test Loss", color="red")
  sns.barplot([time],[1], ax=axes[2], orient="h",label="Time in seconds", color="purple")
  axes[0].set_title('Train Loss')
  axes[0].set_xlabel('Iteration')
  axes[0].set_ylabel('Loss')
  axes[1].set_title('Test Loss')
  axes[1].set_xlabel('Iteration')
  axes[1].set_ylabel('Loss')
  axes[2].set_title('Time')
  axes[2].set_xlabel('Time')
  plt.legend()
  plt.show()

# %%
start = time.time()
train_loss, test_loss = train_and_test_nn(epoch_number=10,show_loss_round=1000)
end = time.time()
total_time_cpu = end - start
print(total_time_cpu)
# Out:
# [1,  1000] loss: 2.303
# [1,  2000] loss: 2.299
# [1,  3000] loss: 1.928
# [1,  4000] loss: 0.926
# [1,  5000] loss: 0.773
# [1,  6000] loss: 0.694
# [1,  7000] loss: 0.685
# [1,  8000] loss: 0.635
# [1,  9000] loss: 0.581
# [1, 10000] loss: 0.590
# [1, 11000] loss: 0.579
# [1, 12000] loss: 0.587
# [1, 13000] loss: 0.537
# [1, 14000] loss: 0.538
# [1, 15000] loss: 0.529
# [2,  1000] loss: 0.515
# [2,  2000] loss: 0.486
# [2,  3000] loss: 0.500
# [2,  4000] loss: 0.490
# [2,  5000] loss: 0.489
# [2,  6000] loss: 0.476
# [2,  7000] loss: 0.452
# [2,  8000] loss: 0.459
# [2,  9000] loss: 0.447
# [2, 10000] loss: 0.458
# [2, 11000] loss: 0.435
# [2, 12000] loss: 0.414
# [2, 13000] loss: 0.425
# [2, 14000] loss: 0.446
# [2, 15000] loss: 0.423
# [3,  1000] loss: 0.410
# [3,  2000] loss: 0.414
# [3,  3000] loss: 0.404
# [3,  4000] loss: 0.388
# [3,  5000] loss: 0.402
# [3,  6000] loss: 0.421
# [3,  7000] loss: 0.392
# [3,  8000] loss: 0.395
# [3,  9000] loss: 0.379
# [3, 10000] loss: 0.389
# [3, 11000] loss: 0.391
# [3, 12000] loss: 0.380
# [3, 13000] loss: 0.372
# [3, 14000] loss: 0.367
# [3, 15000] loss: 0.366
# [4,  1000] loss: 0.351
# [4,  2000] loss: 0.358
# [4,  3000] loss: 0.339
# [4,  4000] loss: 0.351
# [4,  5000] loss: 0.370
# [4,  6000] loss: 0.350
# [4,  7000] loss: 0.372
# [4,  8000] loss: 0.349
# [4,  9000] loss: 0.345
# [4, 10000] loss: 0.349
# [4, 11000] loss: 0.335
# [4, 12000] loss: 0.351
# [4, 13000] loss: 0.324
# [4, 14000] loss: 0.341
# [4, 15000] loss: 0.359
# [5,  1000] loss: 0.346
# [5,  2000] loss: 0.325
# [5,  3000] loss: 0.312
# [5,  4000] loss: 0.350
# [5,  5000] loss: 0.345
# [5,  6000] loss: 0.329
# [5,  7000] loss: 0.324
# [5,  8000] loss: 0.323
# [5,  9000] loss: 0.328
# [5, 10000] loss: 0.316
# [5, 11000] loss: 0.326
# [5, 12000] loss: 0.337
# [5, 13000] loss: 0.313
# [5, 14000] loss: 0.292
# [5, 15000] loss: 0.320
# [6,  1000] loss: 0.302
# [6,  2000] loss: 0.316
# [6,  3000] loss: 0.294
# [6,  4000] loss: 0.306
# [6,  5000] loss: 0.323
# [6,  6000] loss: 0.302
# [6,  7000] loss: 0.304
# [6,  8000] loss: 0.302
# [6,  9000] loss: 0.323
# [6, 10000] loss: 0.318
# [6, 11000] loss: 0.307
# [6, 12000] loss: 0.321
# [6, 13000] loss: 0.309
# [6, 14000] loss: 0.306
# [6, 15000] loss: 0.289
# [7,  1000] loss: 0.284
# [7,  2000] loss: 0.310
# [7,  3000] loss: 0.316
# [7,  4000] loss: 0.285
# [7,  5000] loss: 0.290
# [7,  6000] loss: 0.298
# [7,  7000] loss: 0.288
# [7,  8000] loss: 0.311
# [7,  9000] loss: 0.299
# [7, 10000] loss: 0.297
# [7, 11000] loss: 0.268
# [7, 12000] loss: 0.292
# [7, 13000] loss: 0.306
# [7, 14000] loss: 0.286
# [7, 15000] loss: 0.287
# [8,  1000] loss: 0.298
# [8,  2000] loss: 0.283
# [8,  3000] loss: 0.284
# [8,  4000] loss: 0.269
# [8,  5000] loss: 0.291
# [8,  6000] loss: 0.292
# [8,  7000] loss: 0.275
# [8,  8000] loss: 0.282
# [8,  9000] loss: 0.290
# [8, 10000] loss: 0.270
# [8, 11000] loss: 0.273
# [8, 12000] loss: 0.293
# [8, 13000] loss: 0.286
# [8, 14000] loss: 0.268
# [8, 15000] loss: 0.287
# [9,  1000] loss: 0.274
# [9,  2000] loss: 0.278
# [9,  3000] loss: 0.288
# [9,  4000] loss: 0.276
# [9,  5000] loss: 0.275
# [9,  6000] loss: 0.275
# [9,  7000] loss: 0.272
# [9,  8000] loss: 0.274
# [9,  9000] loss: 0.280
# [9, 10000] loss: 0.269
# [9, 11000] loss: 0.261
# [9, 12000] loss: 0.275
# [9, 13000] loss: 0.261
# [9, 14000] loss: 0.283
# [9, 15000] loss: 0.282
# [10,  1000] loss: 0.265
# [10,  2000] loss: 0.273
# [10,  3000] loss: 0.267
# [10,  4000] loss: 0.268
# [10,  5000] loss: 0.255
# [10,  6000] loss: 0.251
# [10,  7000] loss: 0.273
# [10,  8000] loss: 0.267
# [10,  9000] loss: 0.272
# [10, 10000] loss: 0.265
# [10, 11000] loss: 0.254
# [10, 12000] loss: 0.269
# [10, 13000] loss: 0.264
# [10, 14000] loss: 0.270
# [10, 15000] loss: 0.271
# Finished training, look below for time:
# 594.7043542861938

# %%
plot_loss(train_loss, test_loss, total_time_cpu, 10)

# %% [markdown]
# Write a function that evaluates the resulted model over the entire test data of FashionMNIST. Provide a single accuracy number.

# %%
def compute_accuracy(GPU=False):
  correct = 0
  total = 0
  with torch.no_grad():
      for data in testloader:
          images, labels = data
          if GPU:
            images = images.cuda() # -- For GPU
            labels = labels.cuda() # -- For GPU
          
       
          h, outputs = net(images)
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()
  print('Accuracy of the network on the test images: %d %%' % (100 * correct / total))
  return (100 * correct / total)

# %%
compute_accuracy()
# Out:
# Accuracy of the network on the test images: 89 %

# %% [markdown]
# # **Part 2**: Training with a GPU
# You are requested to change your code to use the GPU instead of the CPU.
# This can be easily done bu converting every torch.tensor to torch.cuda.tensor.
#
# Specific instructions:
# * Change the hardware equipent of your colab notebook. To do that, go to the "Runtime" menu, and then to "Change runtime type". In the dialog box, change "Hardware accelerator" to GPU.
# * Please follow the lines that were commented out with the comment    # -- For GPU
# * Also, remove the lines that have the comment # -- For CPU
#
# Train your network again and compare training time.

# %%
net = CNNFMnist().cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
print(net)
# Out:
# CNNFMnist(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 5, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(5, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
start = time.time()
train_loss_gpu, test_loss_gpu = train_and_test_nn(epoch_number=10,show_loss_round=1000, GPU=True)
end = time.time()
total_time_gpu = end - start
print(total_time_cpu)
# Out:
# [1,  1000] loss: 2.304
# [1,  2000] loss: 2.244
# [1,  3000] loss: 1.236
# [1,  4000] loss: 0.980
# [1,  5000] loss: 0.844
# [1,  6000] loss: 0.735
# [1,  7000] loss: 0.703
# [1,  8000] loss: 0.648
# [1,  9000] loss: 0.631
# [1, 10000] loss: 0.607
# [1, 11000] loss: 0.592
# [1, 12000] loss: 0.555
# [1, 13000] loss: 0.541
# [1, 14000] loss: 0.539
# [1, 15000] loss: 0.506
# [2,  1000] loss: 0.496
# [2,  2000] loss: 0.494
# [2,  3000] loss: 0.510
# [2,  4000] loss: 0.495
# [2,  5000] loss: 0.479
# [2,  6000] loss: 0.465
# [2,  7000] loss: 0.467
# [2,  8000] loss: 0.450
# [2,  9000] loss: 0.441
# [2, 10000] loss: 0.445
# [2, 11000] loss: 0.445
# [2, 12000] loss: 0.420
# [2, 13000] loss: 0.442
# [2, 14000] loss: 0.430
# [2, 15000] loss: 0.396
# [3,  1000] loss: 0.398
# [3,  2000] loss: 0.409
# [3,  3000] loss: 0.402
# [3,  4000] loss: 0.425
# [3,  5000] loss: 0.390
# [3,  6000] loss: 0.403
# [3,  7000] loss: 0.389
# [3,  8000] loss: 0.389
# [3,  9000] loss: 0.402
# [3, 10000] loss: 0.375
# [3, 11000] loss: 0.375
# [3, 12000] loss: 0.383
# [3, 13000] loss: 0.372
# [3, 14000] loss: 0.385
# [3, 15000] loss: 0.366
# [4,  1000] loss: 0.351
# [4,  2000] loss: 0.356
# [4,  3000] loss: 0.370
# [4,  4000] loss: 0.374
# [4,  5000] loss: 0.343
# [4,  6000] loss: 0.354
# [4,  7000] loss: 0.363
# [4,  8000] loss: 0.356
# [4,  9000] loss: 0.356
# [4, 10000] loss: 0.364
# [4, 11000] loss: 0.353
# [4, 12000] loss: 0.347
# [4, 13000] loss: 0.346
# [4, 14000] loss: 0.355
# [4, 15000] loss: 0.328
# [5,  1000] loss: 0.327
# [5,  2000] loss: 0.327
# [5,  3000] loss: 0.329
# [5,  4000] loss: 0.337
# [5,  5000] loss: 0.338
# [5,  6000] loss: 0.316
# [5,  7000] loss: 0.331
# [5,  8000] loss: 0.333
# [5,  9000] loss: 0.342
# [5, 10000] loss: 0.322
# [5, 11000] loss: 0.347
# [5, 12000] loss: 0.334
# [5, 13000] loss: 0.333
# [5, 14000] loss: 0.305
# [5, 15000] loss: 0.333
# [6,  1000] loss: 0.310
# [6,  2000] loss: 0.301
# [6,  3000] loss: 0.323
# [6,  4000] loss: 0.330
# [6,  5000] loss: 0.317
# [6,  6000] loss: 0.316
# [6,  7000] loss: 0.330
# [6,  8000] loss: 0.286
# [6,  9000] loss: 0.306
# [6, 10000] loss: 0.296
# [6, 11000] loss: 0.329
# [6, 12000] loss: 0.310
# [6, 13000] loss: 0.322
# [6, 14000] loss: 0.310
# [6, 15000] loss: 0.302
# [7,  1000] loss: 0.300
# [7,  2000] loss: 0.291
# [7,  3000] loss: 0.294
# [7,  4000] loss: 0.301
# [7,  5000] loss: 0.313
# [7,  6000] loss: 0.307
# [7,  7000] loss: 0.299
# [7,  8000] loss: 0.299
# [7,  9000] loss: 0.291
# [7, 10000] loss: 0.288
# [7, 11000] loss: 0.288
# [7, 12000] loss: 0.287
# [7, 13000] loss: 0.288
# [7, 14000] loss: 0.335
# [7, 15000] loss: 0.309
# [8,  1000] loss: 0.289
# [8,  2000] loss: 0.270
# [8,  3000] loss: 0.283
# [8,  4000] loss: 0.304
# [8,  5000] loss: 0.278
# [8,  6000] loss: 0.266
# [8,  7000] loss: 0.301
# [8,  8000] loss: 0.290
# [8,  9000] loss: 0.294
# [8, 10000] loss: 0.299
# [8, 11000] loss: 0.287
# [8, 12000] loss: 0.278
# [8, 13000] loss: 0.293
# [8, 14000] loss: 0.295
# [8, 15000] loss: 0.314
# [9,  1000] loss: 0.276
# [9,  2000] loss: 0.259
# [9,  3000] loss: 0.274
# [9,  4000] loss: 0.265
# [9,  5000] loss: 0.285
# [9,  6000] loss: 0.291
# [9,  7000] loss: 0.295
# [9,  8000] loss: 0.269
# [9,  9000] loss: 0.280
# [9, 10000] loss: 0.289
# [9, 11000] loss: 0.262
# [9, 12000] loss: 0.308
# [9, 13000] loss: 0.282
# [9, 14000] loss: 0.268
# [9, 15000] loss: 0.283
# [10,  1000] loss: 0.266
# [10,  2000] loss: 0.261
# [10,  3000] loss: 0.260
# [10,  4000] loss: 0.268
# [10,  5000] loss: 0.274
# [10,  6000] loss: 0.256
# [10,  7000] loss: 0.276
# [10,  8000] loss: 0.290
# [10,  9000] loss: 0.281
# [10, 10000] loss: 0.283
# [10, 11000] loss: 0.270
# [10, 12000] loss: 0.273
# [10, 13000] loss: 0.257
# [10, 14000] loss: 0.280
# [10, 15000] loss: 0.253
# Finished training, look below for time:
# 594.7043542861938

# %%
plot_loss(train_loss_gpu, test_loss_gpu,total_time_gpu, 10)

# %% [markdown]
# # **Part 3**: Transfer Learning
# Training data is a valuable resource, and sometimes there is not enough of it for training a neural netowrk at scale. To handle this situation, one approach is transfer learning, where we train our network on a different related task, and then switch to train it on the downstream task that we focus on. In this last part of the assignment, you are requested to pretrain your network on CIFAR-10, then train it on Fashion-MNIST, and measure its contribution to the results. To do that, please follow the steps:
#
# **Step 1**
#
# Modify your CNNFMnist implementation to return the output of the layer one before last after Relu (Linear layer of size 64, above) in addition to the final output. For example:
#
# ```
# def forward(self, x):
#   ...
#   return h, out
# ```
#
#  and train it on the training-set part of CIFAR-10. Use batch size of 4, and train it for at least 10 epochs. Note that CIFAR-10 images are of different shapes (3X32X32), therefore a conversion into 1X28X28 is needed. To do that, when you load CIFAR-10 using a torchvision Dataset, you can use the transformer torchvision.transforms.Grayscale(num_output_channels=1) in order to convert the images to a 1X32X32 grayscale volume:
#
# ```
# trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
#                                         download=True, transform=torchvision.transforms.Compose([torchvision.transforms.Grayscale(num_output_channels=1),
#                                     torchvision.transforms.ToTensor()]))
# ```
# Then, from each 1X32X32 image, sample 10 1X28X28 images at random positions, and use them for training (*optional* - for data augmentation, if you want, you can also generate the reflection of each of the 10 images and add them the training set).
#
# **Setp 2**
#
# Once done, write a new Module CNNFMnist2, which uses CNNFMnist as one of its sub modules, followed by some additional layers. The output of CNNFMnist that goes into the next layer, should be the output of the 64 neuron one-before-last layer, as described above. CNNFMnist2 should have the following architecture:
#
# * CNNFMnist
# * Liner, output size 32
# * Relu
# * Liner, output size 16
# * Relu
# * Liner, output size 10
#
# Make sure to allow the user to assign a pre-trained version CNNFMnist as a member of the module. For example:
#
# ```
# class CNNFMnist2(nn.Module):
#     def __init__(self, trained_cnnfmnist_model):
#         super(CNNFMnist2, self).__init__()
#         self.trained_cnnfmnist_model = trained_cnnfmnist_model
#         self.fc1 = nn.Linear(64, 32)
#         ...
# ```
#
# **Step 3**
#
# Train and eval CNNFMnist2 on Fashion-MNIST a few times:
# - Using the pre-trained version of CNNFMnist.
# - Using a fresh CNNFMnist instance (without training it).
# - (Optional) Using the pre-trained version of CNNFMnist, after freezing its weights using the .eval() function.
#
# Report on evaluation results (accuracy) for all of those cases.

# %%
class CNNFMnist(nn.Module):

    def __init__(self):
        super(CNNFMnist, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, 3) # 10 chanels of 26*26
        #max pooling create 13*13
        self.conv2 = nn.Conv2d(10, 5, 3) # 5 chanels of 11*11
        self.conv3 = nn.Conv2d(5, 16, 3) # 16 chanels of 9*9
        #max pooling create 4*4
        self.fc1 = nn.Linear(16 * 4 * 4, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(F.relu(self.conv3(x)), (2, 2))
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.fc1(x))
        h = self.fc2(x)
        x = F.relu(h)
        x = self.fc3(x)
        return h, x

# %%
class CNNFMnist2(nn.Module):
    def __init__(self, trained_cnnfmnist_model):
        super(CNNFMnist2, self).__init__()
        self.trained_cnnfmnist_model = trained_cnnfmnist_model
        self.fc1 = nn.Linear(64, 32).cuda()
        self.fc2 = nn.Linear(32, 16).cuda()
        self.fc3 = nn.Linear(16, 10).cuda()

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
trainset, testset,trainloader,testloader = load_cifar10_data()
trainset[0][0].shape
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([1, 28, 28])

# %% [markdown]
# STEP 3

# %% [markdown]
# ##### 3.1 Pre-trained Net

# %%
net = CNNFMnist().cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
print(net)
# Out:
# CNNFMnist(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 5, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(5, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
start = time.time()
train_loss_gpu_1, test_loss_gpu_1 = train_and_test_nn(epoch_number=10,show_loss_round=1000, GPU=True)
end = time.time()
total_time_gpu_3_1 = end - start
print(total_time_gpu_3_1)
# Out:
# [1,  1000] loss: 2.303
# [1,  2000] loss: 2.303
# [1,  3000] loss: 2.303
# [1,  4000] loss: 2.303
# [1,  5000] loss: 2.302
# [1,  6000] loss: 2.301
# [1,  7000] loss: 2.300
# [1,  8000] loss: 2.296
# [1,  9000] loss: 2.283
# [1, 10000] loss: 2.271
# [1, 11000] loss: 2.257
# [1, 12000] loss: 2.246
# [1, 13000] loss: 2.227
# [1, 14000] loss: 2.225
# [1, 15000] loss: 2.227
# [1, 16000] loss: 2.210
# [1, 17000] loss: 2.199
# [1, 18000] loss: 2.192
# [1, 19000] loss: 2.175
# [1, 20000] loss: 2.166
# [1, 21000] loss: 2.138
# [1, 22000] loss: 2.136
# [1, 23000] loss: 2.123
# [1, 24000] loss: 2.113
# [1, 25000] loss: 2.108
# [1, 26000] loss: 2.110
# [1, 27000] loss: 2.084
# [1, 28000] loss: 2.088
# [1, 29000] loss: 2.072
# [1, 30000] loss: 2.065
# [1, 31000] loss: 2.058
# [1, 32000] loss: 2.052
# [1, 33000] loss: 2.044
# [1, 34000] loss: 2.052
# [1, 35000] loss: 2.038
# [1, 36000] loss: 2.024
# [1, 37000] loss: 2.034
# [1, 38000] loss: 2.022
# [1, 39000] loss: 2.021
# [1, 40000] loss: 2.007
# [1, 41000] loss: 2.015
# [1, 42000] loss: 2.021
# [1, 43000] loss: 1.987
# [1, 44000] loss: 1.987
# [1, 45000] loss: 1.991
# [1, 46000] loss: 1.992
# [1, 47000] loss: 1.969
# [1, 48000] loss: 1.985
# [1, 49000] loss: 1.970
# [1, 50000] loss: 1.966
# [1, 51000] loss: 1.973
# [1, 52000] loss: 1.966
# [1, 53000] loss: 1.956
# [1, 54000] loss: 1.964
# [1, 55000] loss: 1.937
# [1, 56000] loss: 1.938
# [1, 57000] loss: 1.943
# [1, 58000] loss: 1.945
# [1, 59000] loss: 1.963
# [1, 60000] loss: 1.929
# [1, 61000] loss: 1.960
# [1, 62000] loss: 1.934
# [1, 63000] loss: 1.934
# [1, 64000] loss: 1.908
# [1, 65000] loss: 1.915
# [1, 66000] loss: 1.914
# [1, 67000] loss: 1.921
# [1, 68000] loss: 1.918
# [1, 69000] loss: 1.943
# [1, 70000] loss: 1.906
# [1, 71000] loss: 1.909
# [1, 72000] loss: 1.914
# [1, 73000] loss: 1.898
# [1, 74000] loss: 1.910
# [1, 75000] loss: 1.923
# [1, 76000] loss: 1.918
# [1, 77000] loss: 1.912
# [1, 78000] loss: 1.878
# [1, 79000] loss: 1.889
# [1, 80000] loss: 1.878
# [1, 81000] loss: 1.892
# [1, 82000] loss: 1.889
# [1, 83000] loss: 1.878
# [1, 84000] loss: 1.884
# [1, 85000] loss: 1.885
# [1, 86000] loss: 1.867
# [1, 87000] loss: 1.874
# [1, 88000] loss: 1.882
# [1, 89000] loss: 1.882
# [1, 90000] loss: 1.882
# [1, 91000] loss: 1.871
# [1, 92000] loss: 1.864
# [1, 93000] loss: 1.890
# [1, 94000] loss: 1.867
# [1, 95000] loss: 1.876
# [1, 96000] loss: 1.874
# [1, 97000] loss: 1.842
# [1, 98000] loss: 1.865
# [1, 99000] loss: 1.852
# [1, 100000] loss: 1.828
# [1, 101000] loss: 1.851
# [1, 102000] loss: 1.847
# [1, 103000] loss: 1.836
# [1, 104000] loss: 1.831
# [1, 105000] loss: 1.855
# [1, 106000] loss: 1.842
# [1, 107000] loss: 1.875
# [1, 108000] loss: 1.823
# [1, 109000] loss: 1.845
# [1, 110000] loss: 1.809
# [1, 111000] loss: 1.820
# [1, 112000] loss: 1.835
# [1, 113000] loss: 1.806
# [1, 114000] loss: 1.826
# [1, 115000] loss: 1.807
# [1, 116000] loss: 1.817
# [1, 117000] loss: 1.817
# [1, 118000] loss: 1.834
# [1, 119000] loss: 1.801
# [1, 120000] loss: 1.804
# [1, 121000] loss: 1.807
# [1, 122000] loss: 1.830
# [1, 123000] loss: 1.804
# [1, 124000] loss: 1.808
# [1, 125000] loss: 1.798
# [2,  1000] loss: 1.811
# [2,  2000] loss: 1.793
# [2,  3000] loss: 1.790
# [2,  4000] loss: 1.794
# [2,  5000] loss: 1.771
# [2,  6000] loss: 1.805
# [2,  7000] loss: 1.795
# [2,  8000] loss: 1.793
# [2,  9000] loss: 1.788
# [2, 10000] loss: 1.782
# [2, 11000] loss: 1.815
# [2, 12000] loss: 1.786
# [2, 13000] loss: 1.761
# [2, 14000] loss: 1.803
# [2, 15000] loss: 1.784
# [2, 16000] loss: 1.780
# [2, 17000] loss: 1.786
# [2, 18000] loss: 1.768
# [2, 19000] loss: 1.778
# [2, 20000] loss: 1.755
# [2, 21000] loss: 1.788
# [2, 22000] loss: 1.766
# [2, 23000] loss: 1.744
# [2, 24000] loss: 1.788
# [2, 25000] loss: 1.775
# [2, 26000] loss: 1.761
# [2, 27000] loss: 1.739
# [2, 28000] loss: 1.772
# [2, 29000] loss: 1.736
# [2, 30000] loss: 1.777
# [2, 31000] loss: 1.806
# [2, 32000] loss: 1.755
# [2, 33000] loss: 1.750
# [2, 34000] loss: 1.755
# [2, 35000] loss: 1.726
# [2, 36000] loss: 1.754
# [2, 37000] loss: 1.789
# [2, 38000] loss: 1.776
# [2, 39000] loss: 1.748
# [2, 40000] loss: 1.757
# [2, 41000] loss: 1.756
# [2, 42000] loss: 1.760
# [2, 43000] loss: 1.756
# [2, 44000] loss: 1.763
# [2, 45000] loss: 1.737
# [2, 46000] loss: 1.753
# [2, 47000] loss: 1.748
# [2, 48000] loss: 1.744
# [2, 49000] loss: 1.768
# [2, 50000] loss: 1.756
# [2, 51000] loss: 1.739
# [2, 52000] loss: 1.731
# [2, 53000] loss: 1.750
# [2, 54000] loss: 1.709
# [2, 55000] loss: 1.728
# [2, 56000] loss: 1.749
# [2, 57000] loss: 1.697
# [2, 58000] loss: 1.734
# [2, 59000] loss: 1.721
# [2, 60000] loss: 1.721
# [2, 61000] loss: 1.739
# [2, 62000] loss: 1.725
# [2, 63000] loss: 1.742
# [2, 64000] loss: 1.716
# [2, 65000] loss: 1.712
# [2, 66000] loss: 1.738
# [2, 67000] loss: 1.697
# [2, 68000] loss: 1.717
# [2, 69000] loss: 1.694
# [2, 70000] loss: 1.733
# [2, 71000] loss: 1.734
# [2, 72000] loss: 1.715
# [2, 73000] loss: 1.734
# [2, 74000] loss: 1.729
# [2, 75000] loss: 1.711
# [2, 76000] loss: 1.735
# [2, 77000] loss: 1.721
# [2, 78000] loss: 1.741
# [2, 79000] loss: 1.710
# [2, 80000] loss: 1.739
# [2, 81000] loss: 1.719
# [2, 82000] loss: 1.705
# [2, 83000] loss: 1.694
# [2, 84000] loss: 1.727
# [2, 85000] loss: 1.712
# [2, 86000] loss: 1.678
# [2, 87000] loss: 1.742
# [2, 88000] loss: 1.724
# [2, 89000] loss: 1.719
# [2, 90000] loss: 1.723
# [2, 91000] loss: 1.693
# [2, 92000] loss: 1.689
# [2, 93000] loss: 1.711
# [2, 94000] loss: 1.700
# [2, 95000] loss: 1.710
# [2, 96000] loss: 1.704
# [2, 97000] loss: 1.709
# [2, 98000] loss: 1.717
# [2, 99000] loss: 1.708
# [2, 100000] loss: 1.718
# [2, 101000] loss: 1.697
# [2, 102000] loss: 1.728
# [2, 103000] loss: 1.713
# [2, 104000] loss: 1.700
# [2, 105000] loss: 1.698
# [2, 106000] loss: 1.698
# [2, 107000] loss: 1.706
# [2, 108000] loss: 1.701
# [2, 109000] loss: 1.707
# [2, 110000] loss: 1.704
# [2, 111000] loss: 1.678
# [2, 112000] loss: 1.722
# [2, 113000] loss: 1.728
# [2, 114000] loss: 1.681
# [2, 115000] loss: 1.726
# [2, 116000] loss: 1.710
# [2, 117000] loss: 1.704
# [2, 118000] loss: 1.712
# [2, 119000] loss: 1.717
# [2, 120000] loss: 1.661
# [2, 121000] loss: 1.714
# [2, 122000] loss: 1.711
# [2, 123000] loss: 1.705
# [2, 124000] loss: 1.705
# [2, 125000] loss: 1.712
# [3,  1000] loss: 1.694
# [3,  2000] loss: 1.708
# [3,  3000] loss: 1.700
# [3,  4000] loss: 1.708
# [3,  5000] loss: 1.675
# [3,  6000] loss: 1.693
# [3,  7000] loss: 1.675
# [3,  8000] loss: 1.679
# [3,  9000] loss: 1.692
# [3, 10000] loss: 1.696
# [3, 11000] loss: 1.676
# [3, 12000] loss: 1.675
# [3, 13000] loss: 1.688
# [3, 14000] loss: 1.664
# [3, 15000] loss: 1.695
# [3, 16000] loss: 1.705
# [3, 17000] loss: 1.686
# [3, 18000] loss: 1.636
# [3, 19000] loss: 1.670
# [3, 20000] loss: 1.694
# [3, 21000] loss: 1.696
# [3, 22000] loss: 1.705
# [3, 23000] loss: 1.649
# [3, 24000] loss: 1.675
# [3, 25000] loss: 1.649
# [3, 26000] loss: 1.680
# [3, 27000] loss: 1.686
# [3, 28000] loss: 1.664
# [3, 29000] loss: 1.679
# [3, 30000] loss: 1.696
# [3, 31000] loss: 1.701
# [3, 32000] loss: 1.660
# [3, 33000] loss: 1.667
# [3, 34000] loss: 1.661
# [3, 35000] loss: 1.664
# [3, 36000] loss: 1.671
# [3, 37000] loss: 1.653
# [3, 38000] loss: 1.650
# [3, 39000] loss: 1.686
# [3, 40000] loss: 1.692
# [3, 41000] loss: 1.662
# [3, 42000] loss: 1.687
# [3, 43000] loss: 1.664
# [3, 44000] loss: 1.670
# [3, 45000] loss: 1.640
# [3, 46000] loss: 1.664
# [3, 47000] loss: 1.693
# [3, 48000] loss: 1.681
# [3, 49000] loss: 1.677
# [3, 50000] loss: 1.658
# [3, 51000] loss: 1.685
# [3, 52000] loss: 1.646
# [3, 53000] loss: 1.709
# [3, 54000] loss: 1.695
# [3, 55000] loss: 1.669
# [3, 56000] loss: 1.697
# [3, 57000] loss: 1.687
# [3, 58000] loss: 1.655
# [3, 59000] loss: 1.642
# [3, 60000] loss: 1.658
# [3, 61000] loss: 1.681
# [3, 62000] loss: 1.698
# [3, 63000] loss: 1.684
# [3, 64000] loss: 1.678
# [3, 65000] loss: 1.643
# [3, 66000] loss: 1.673
# [3, 67000] loss: 1.665
# [3, 68000] loss: 1.670
# [3, 69000] loss: 1.664
# [3, 70000] loss: 1.657
# [3, 71000] loss: 1.658
# [3, 72000] loss: 1.660
# [3, 73000] loss: 1.636
# [3, 74000] loss: 1.675
# [3, 75000] loss: 1.626
# [3, 76000] loss: 1.691
# [3, 77000] loss: 1.681
# [3, 78000] loss: 1.677
# [3, 79000] loss: 1.666
# [3, 80000] loss: 1.676
# [3, 81000] loss: 1.645
# [3, 82000] loss: 1.666
# [3, 83000] loss: 1.645
# [3, 84000] loss: 1.667
# [3, 85000] loss: 1.663
# [3, 86000] loss: 1.662
# [3, 87000] loss: 1.664
# [3, 88000] loss: 1.664
# [3, 89000] loss: 1.632
# [3, 90000] loss: 1.642
# [3, 91000] loss: 1.649
# [3, 92000] loss: 1.682
# [3, 93000] loss: 1.662
# [3, 94000] loss: 1.638
# [3, 95000] loss: 1.682
# [3, 96000] loss: 1.660
# [3, 97000] loss: 1.655
# [3, 98000] loss: 1.651
# [3, 99000] loss: 1.670
# [3, 100000] loss: 1.666
# [3, 101000] loss: 1.665
# [3, 102000] loss: 1.648
# [3, 103000] loss: 1.667
# [3, 104000] loss: 1.642
# [3, 105000] loss: 1.667
# [3, 106000] loss: 1.672
# [3, 107000] loss: 1.672
# [3, 108000] loss: 1.654
# [3, 109000] loss: 1.661
# [3, 110000] loss: 1.656
# [3, 111000] loss: 1.684
# [3, 112000] loss: 1.673
# [3, 113000] loss: 1.653
# [3, 114000] loss: 1.663
# [3, 115000] loss: 1.665
# [3, 116000] loss: 1.672
# [3, 117000] loss: 1.640
# [3, 118000] loss: 1.640
# [3, 119000] loss: 1.688
# [3, 120000] loss: 1.654
# [3, 121000] loss: 1.651
# [3, 122000] loss: 1.628
# [3, 123000] loss: 1.666
# [3, 124000] loss: 1.654
# [3, 125000] loss: 1.669
# [4,  1000] loss: 1.645
# [4,  2000] loss: 1.694
# [4,  3000] loss: 1.674
# [4,  4000] loss: 1.663
# [4,  5000] loss: 1.667
# [4,  6000] loss: 1.631
# [4,  7000] loss: 1.681
# [4,  8000] loss: 1.636
# [4,  9000] loss: 1.641
# [4, 10000] loss: 1.641
# [4, 11000] loss: 1.667
# [4, 12000] loss: 1.659
# [4, 13000] loss: 1.666
# [4, 14000] loss: 1.654
# [4, 15000] loss: 1.647
# [4, 16000] loss: 1.621
# [4, 17000] loss: 1.664
# [4, 18000] loss: 1.672
# [4, 19000] loss: 1.652
# [4, 20000] loss: 1.687
# [4, 21000] loss: 1.651
# [4, 22000] loss: 1.670
# [4, 23000] loss: 1.619
# [4, 24000] loss: 1.631
# [4, 25000] loss: 1.632
# [4, 26000] loss: 1.667
# [4, 27000] loss: 1.658
# [4, 28000] loss: 1.649
# [4, 29000] loss: 1.633
# [4, 30000] loss: 1.654
# [4, 31000] loss: 1.647
# [4, 32000] loss: 1.648
# [4, 33000] loss: 1.642
# [4, 34000] loss: 1.640
# [4, 35000] loss: 1.656
# [4, 36000] loss: 1.643
# [4, 37000] loss: 1.637
# [4, 38000] loss: 1.663
# [4, 39000] loss: 1.638
# [4, 40000] loss: 1.656
# [4, 41000] loss: 1.659
# [4, 42000] loss: 1.632
# [4, 43000] loss: 1.646
# [4, 44000] loss: 1.630
# [4, 45000] loss: 1.634
# [4, 46000] loss: 1.655
# [4, 47000] loss: 1.653
# [4, 48000] loss: 1.671
# [4, 49000] loss: 1.666
# [4, 50000] loss: 1.661
# [4, 51000] loss: 1.630
# [4, 52000] loss: 1.647
# [4, 53000] loss: 1.681
# [4, 54000] loss: 1.664
# [4, 55000] loss: 1.642
# [4, 56000] loss: 1.664
# [4, 57000] loss: 1.633
# [4, 58000] loss: 1.685
# [4, 59000] loss: 1.629
# [4, 60000] loss: 1.650
# [4, 61000] loss: 1.652
# [4, 62000] loss: 1.651
# [4, 63000] loss: 1.635
# [4, 64000] loss: 1.641
# [4, 65000] loss: 1.623
# [4, 66000] loss: 1.627
# [4, 67000] loss: 1.629
# [4, 68000] loss: 1.619
# [4, 69000] loss: 1.664
# [4, 70000] loss: 1.663
# [4, 71000] loss: 1.642
# [4, 72000] loss: 1.625
# [4, 73000] loss: 1.643
# [4, 74000] loss: 1.632
# [4, 75000] loss: 1.648
# [4, 76000] loss: 1.650
# [4, 77000] loss: 1.618
# [4, 78000] loss: 1.642
# [4, 79000] loss: 1.664
# [4, 80000] loss: 1.640
# [4, 81000] loss: 1.653
# [4, 82000] loss: 1.654
# [4, 83000] loss: 1.668
# [4, 84000] loss: 1.643
# [4, 85000] loss: 1.655
# [4, 86000] loss: 1.633
# [4, 87000] loss: 1.683
# [4, 88000] loss: 1.633
# [4, 89000] loss: 1.662
# [4, 90000] loss: 1.647
# [4, 91000] loss: 1.653
# [4, 92000] loss: 1.624
# [4, 93000] loss: 1.653
# [4, 94000] loss: 1.636
# [4, 95000] loss: 1.656
# [4, 96000] loss: 1.660
# [4, 97000] loss: 1.636
# [4, 98000] loss: 1.649
# [4, 99000] loss: 1.669
# [4, 100000] loss: 1.632
# [4, 101000] loss: 1.630
# [4, 102000] loss: 1.609
# [4, 103000] loss: 1.637
# [4, 104000] loss: 1.616
# [4, 105000] loss: 1.651
# [4, 106000] loss: 1.640
# [4, 107000] loss: 1.640
# [4, 108000] loss: 1.655
# [4, 109000] loss: 1.649
# [4, 110000] loss: 1.627
# [4, 111000] loss: 1.627
# [4, 112000] loss: 1.666
# [4, 113000] loss: 1.655
# [4, 114000] loss: 1.630
# [4, 115000] loss: 1.622
# [4, 116000] loss: 1.626
# [4, 117000] loss: 1.629
# [4, 118000] loss: 1.636
# [4, 119000] loss: 1.665
# [4, 120000] loss: 1.661
# [4, 121000] loss: 1.646
# [4, 122000] loss: 1.632
# [4, 123000] loss: 1.635
# [4, 124000] loss: 1.617
# [4, 125000] loss: 1.640
# [5,  1000] loss: 1.648
# [5,  2000] loss: 1.640
# [5,  3000] loss: 1.650
# [5,  4000] loss: 1.625
# [5,  5000] loss: 1.629
# [5,  6000] loss: 1.622
# [5,  7000] loss: 1.625
# [5,  8000] loss: 1.642
# [5,  9000] loss: 1.621
# [5, 10000] loss: 1.639
# [5, 11000] loss: 1.645
# [5, 12000] loss: 1.665
# [5, 13000] loss: 1.619
# [5, 14000] loss: 1.613
# [5, 15000] loss: 1.656
# [5, 16000] loss: 1.634
# [5, 17000] loss: 1.644
# [5, 18000] loss: 1.634
# [5, 19000] loss: 1.645
# [5, 20000] loss: 1.619
# [5, 21000] loss: 1.636
# [5, 22000] loss: 1.637
# [5, 23000] loss: 1.655
# [5, 24000] loss: 1.646
# [5, 25000] loss: 1.635
# [5, 26000] loss: 1.601
# [5, 27000] loss: 1.602
# [5, 28000] loss: 1.627
# [5, 29000] loss: 1.614
# [5, 30000] loss: 1.661
# [5, 31000] loss: 1.641
# [5, 32000] loss: 1.628
# [5, 33000] loss: 1.635
# [5, 34000] loss: 1.632
# [5, 35000] loss: 1.639
# [5, 36000] loss: 1.691
# [5, 37000] loss: 1.634
# [5, 38000] loss: 1.635
# [5, 39000] loss: 1.647
# [5, 40000] loss: 1.638
# [5, 41000] loss: 1.600
# [5, 42000] loss: 1.660
# [5, 43000] loss: 1.634
# [5, 44000] loss: 1.673
# [5, 45000] loss: 1.606
# [5, 46000] loss: 1.645
# [5, 47000] loss: 1.648
# [5, 48000] loss: 1.616
# [5, 49000] loss: 1.599
# [5, 50000] loss: 1.635
# [5, 51000] loss: 1.642
# [5, 52000] loss: 1.633
# [5, 53000] loss: 1.647
# [5, 54000] loss: 1.652
# [5, 55000] loss: 1.623
# [5, 56000] loss: 1.622
# [5, 57000] loss: 1.631
# [5, 58000] loss: 1.612
# [5, 59000] loss: 1.650
# [5, 60000] loss: 1.618
# [5, 61000] loss: 1.629
# [5, 62000] loss: 1.638
# [5, 63000] loss: 1.645
# [5, 64000] loss: 1.623
# [5, 65000] loss: 1.638
# [5, 66000] loss: 1.606
# [5, 67000] loss: 1.615
# [5, 68000] loss: 1.597
# [5, 69000] loss: 1.654
# [5, 70000] loss: 1.612
# [5, 71000] loss: 1.636
# [5, 72000] loss: 1.632
# [5, 73000] loss: 1.613
# [5, 74000] loss: 1.625
# [5, 75000] loss: 1.613
# [5, 76000] loss: 1.647
# [5, 77000] loss: 1.599
# [5, 78000] loss: 1.633
# [5, 79000] loss: 1.621
# [5, 80000] loss: 1.611
# [5, 81000] loss: 1.640
# [5, 82000] loss: 1.624
# [5, 83000] loss: 1.630
# [5, 84000] loss: 1.649
# [5, 85000] loss: 1.635
# [5, 86000] loss: 1.642
# [5, 87000] loss: 1.648
# [5, 88000] loss: 1.629
# [5, 89000] loss: 1.655
# [5, 90000] loss: 1.595
# [5, 91000] loss: 1.626
# [5, 92000] loss: 1.634
# [5, 93000] loss: 1.632
# [5, 94000] loss: 1.626
# [5, 95000] loss: 1.591
# [5, 96000] loss: 1.633
# [5, 97000] loss: 1.640
# [5, 98000] loss: 1.638
# [5, 99000] loss: 1.638
# [5, 100000] loss: 1.589
# [5, 101000] loss: 1.638
# [5, 102000] loss: 1.627
# [5, 103000] loss: 1.605
# [5, 104000] loss: 1.631
# [5, 105000] loss: 1.634
# [5, 106000] loss: 1.658
# [5, 107000] loss: 1.625
# [5, 108000] loss: 1.628
# [5, 109000] loss: 1.617
# [5, 110000] loss: 1.597
# [5, 111000] loss: 1.608
# [5, 112000] loss: 1.635
# [5, 113000] loss: 1.622
# [5, 114000] loss: 1.641
# [5, 115000] loss: 1.607
# [5, 116000] loss: 1.626
# [5, 117000] loss: 1.643
# [5, 118000] loss: 1.626
# [5, 119000] loss: 1.636
# [5, 120000] loss: 1.607
# [5, 121000] loss: 1.634
# [5, 122000] loss: 1.603
# [5, 123000] loss: 1.634
# [5, 124000] loss: 1.644
# [5, 125000] loss: 1.596
# [6,  1000] loss: 1.637
# [6,  2000] loss: 1.580
# [6,  3000] loss: 1.660
# [6,  4000] loss: 1.627
# [6,  5000] loss: 1.642
# [6,  6000] loss: 1.642
# [6,  7000] loss: 1.613
# [6,  8000] loss: 1.639
# [6,  9000] loss: 1.658
# [6, 10000] loss: 1.638
# [6, 11000] loss: 1.630
# [6, 12000] loss: 1.648
# [6, 13000] loss: 1.617
# [6, 14000] loss: 1.652
# [6, 15000] loss: 1.646
# [6, 16000] loss: 1.610
# [6, 17000] loss: 1.599
# [6, 18000] loss: 1.628
# [6, 19000] loss: 1.626
# [6, 20000] loss: 1.616
# [6, 21000] loss: 1.615
# [6, 22000] loss: 1.612
# [6, 23000] loss: 1.621
# [6, 24000] loss: 1.641
# [6, 25000] loss: 1.622
# [6, 26000] loss: 1.644
# [6, 27000] loss: 1.632
# [6, 28000] loss: 1.601
# [6, 29000] loss: 1.638
# [6, 30000] loss: 1.623
# [6, 31000] loss: 1.613
# [6, 32000] loss: 1.639
# [6, 33000] loss: 1.611
# [6, 34000] loss: 1.585
# [6, 35000] loss: 1.624
# [6, 36000] loss: 1.603
# [6, 37000] loss: 1.624
# [6, 38000] loss: 1.640
# [6, 39000] loss: 1.621
# [6, 40000] loss: 1.630
# [6, 41000] loss: 1.633
# [6, 42000] loss: 1.643
# [6, 43000] loss: 1.629
# [6, 44000] loss: 1.641
# [6, 45000] loss: 1.634
# [6, 46000] loss: 1.646
# [6, 47000] loss: 1.676
# [6, 48000] loss: 1.617
# [6, 49000] loss: 1.623
# [6, 50000] loss: 1.636
# [6, 51000] loss: 1.630
# [6, 52000] loss: 1.614
# [6, 53000] loss: 1.637
# [6, 54000] loss: 1.623
# [6, 55000] loss: 1.606
# [6, 56000] loss: 1.612
# [6, 57000] loss: 1.649
# [6, 58000] loss: 1.628
# [6, 59000] loss: 1.635
# [6, 60000] loss: 1.624
# [6, 61000] loss: 1.630
# [6, 62000] loss: 1.617
# [6, 63000] loss: 1.610
# [6, 64000] loss: 1.644
# [6, 65000] loss: 1.623
# [6, 66000] loss: 1.597
# [6, 67000] loss: 1.638
# [6, 68000] loss: 1.620
# [6, 69000] loss: 1.649
# [6, 70000] loss: 1.626
# [6, 71000] loss: 1.635
# [6, 72000] loss: 1.607
# [6, 73000] loss: 1.619
# [6, 74000] loss: 1.642
# [6, 75000] loss: 1.633
# [6, 76000] loss: 1.628
# [6, 77000] loss: 1.623
# [6, 78000] loss: 1.640
# [6, 79000] loss: 1.627
# [6, 80000] loss: 1.639
# [6, 81000] loss: 1.564
# [6, 82000] loss: 1.627
# [6, 83000] loss: 1.599
# [6, 84000] loss: 1.618
# [6, 85000] loss: 1.619
# [6, 86000] loss: 1.612
# [6, 87000] loss: 1.617
# [6, 88000] loss: 1.607
# [6, 89000] loss: 1.611
# [6, 90000] loss: 1.608
# [6, 91000] loss: 1.604
# [6, 92000] loss: 1.658
# [6, 93000] loss: 1.593
# [6, 94000] loss: 1.646
# [6, 95000] loss: 1.626
# [6, 96000] loss: 1.626
# [6, 97000] loss: 1.617
# [6, 98000] loss: 1.626
# [6, 99000] loss: 1.620
# [6, 100000] loss: 1.616
# [6, 101000] loss: 1.613
# [6, 102000] loss: 1.631
# [6, 103000] loss: 1.594
# [6, 104000] loss: 1.597
# [6, 105000] loss: 1.635
# [6, 106000] loss: 1.613
# [6, 107000] loss: 1.632
# [6, 108000] loss: 1.632
# [6, 109000] loss: 1.628
# [6, 110000] loss: 1.609
# [6, 111000] loss: 1.607
# [6, 112000] loss: 1.640
# [6, 113000] loss: 1.600
# [6, 114000] loss: 1.625
# [6, 115000] loss: 1.636
# [6, 116000] loss: 1.610
# [6, 117000] loss: 1.629
# [6, 118000] loss: 1.647
# [6, 119000] loss: 1.653
# [6, 120000] loss: 1.628
# [6, 121000] loss: 1.629
# [6, 122000] loss: 1.593
# [6, 123000] loss: 1.605
# [6, 124000] loss: 1.616
# [6, 125000] loss: 1.636
# [7,  1000] loss: 1.638
# [7,  2000] loss: 1.597
# [7,  3000] loss: 1.584
# [7,  4000] loss: 1.620
# [7,  5000] loss: 1.639
# [7,  6000] loss: 1.587
# [7,  7000] loss: 1.602
# [7,  8000] loss: 1.591
# [7,  9000] loss: 1.605
# [7, 10000] loss: 1.615
# [7, 11000] loss: 1.606
# [7, 12000] loss: 1.626
# [7, 13000] loss: 1.617
# [7, 14000] loss: 1.593
# [7, 15000] loss: 1.601
# [7, 16000] loss: 1.579
# [7, 17000] loss: 1.624
# [7, 18000] loss: 1.636
# [7, 19000] loss: 1.612
# [7, 20000] loss: 1.627
# [7, 21000] loss: 1.592
# [7, 22000] loss: 1.603
# [7, 23000] loss: 1.601
# [7, 24000] loss: 1.612
# [7, 25000] loss: 1.616
# [7, 26000] loss: 1.629
# [7, 27000] loss: 1.591
# [7, 28000] loss: 1.625
# [7, 29000] loss: 1.644
# [7, 30000] loss: 1.601
# [7, 31000] loss: 1.597
# [7, 32000] loss: 1.603
# [7, 33000] loss: 1.607
# [7, 34000] loss: 1.593
# [7, 35000] loss: 1.634
# [7, 36000] loss: 1.620
# [7, 37000] loss: 1.598
# [7, 38000] loss: 1.618
# [7, 39000] loss: 1.599
# [7, 40000] loss: 1.589
# [7, 41000] loss: 1.612
# [7, 42000] loss: 1.620
# [7, 43000] loss: 1.638
# [7, 44000] loss: 1.629
# [7, 45000] loss: 1.624
# [7, 46000] loss: 1.680
# [7, 47000] loss: 1.624
# [7, 48000] loss: 1.599
# [7, 49000] loss: 1.617
# [7, 50000] loss: 1.615
# [7, 51000] loss: 1.607
# [7, 52000] loss: 1.632
# [7, 53000] loss: 1.598
# [7, 54000] loss: 1.614
# [7, 55000] loss: 1.593
# [7, 56000] loss: 1.648
# [7, 57000] loss: 1.616
# [7, 58000] loss: 1.608
# [7, 59000] loss: 1.619
# [7, 60000] loss: 1.589
# [7, 61000] loss: 1.620
# [7, 62000] loss: 1.593
# [7, 63000] loss: 1.623
# [7, 64000] loss: 1.594
# [7, 65000] loss: 1.618
# [7, 66000] loss: 1.608
# [7, 67000] loss: 1.622
# [7, 68000] loss: 1.613
# [7, 69000] loss: 1.620
# [7, 70000] loss: 1.612
# [7, 71000] loss: 1.622
# [7, 72000] loss: 1.619
# [7, 73000] loss: 1.607
# [7, 74000] loss: 1.612
# [7, 75000] loss: 1.630
# [7, 76000] loss: 1.625
# [7, 77000] loss: 1.603
# [7, 78000] loss: 1.635
# [7, 79000] loss: 1.608
# [7, 80000] loss: 1.609
# [7, 81000] loss: 1.614
# [7, 82000] loss: 1.605
# [7, 83000] loss: 1.624
# [7, 84000] loss: 1.608
# [7, 85000] loss: 1.637
# [7, 86000] loss: 1.622
# [7, 87000] loss: 1.613
# [7, 88000] loss: 1.591
# [7, 89000] loss: 1.592
# [7, 90000] loss: 1.610
# [7, 91000] loss: 1.597
# [7, 92000] loss: 1.619
# [7, 93000] loss: 1.616
# [7, 94000] loss: 1.626
# [7, 95000] loss: 1.581
# [7, 96000] loss: 1.609
# [7, 97000] loss: 1.600
# [7, 98000] loss: 1.604
# [7, 99000] loss: 1.604
# [7, 100000] loss: 1.643
# [7, 101000] loss: 1.610
# [7, 102000] loss: 1.631
# [7, 103000] loss: 1.610
# [7, 104000] loss: 1.608
# [7, 105000] loss: 1.619
# [7, 106000] loss: 1.608
# [7, 107000] loss: 1.629
# [7, 108000] loss: 1.589
# [7, 109000] loss: 1.615
# [7, 110000] loss: 1.615
# [7, 111000] loss: 1.615
# [7, 112000] loss: 1.584
# [7, 113000] loss: 1.617
# [7, 114000] loss: 1.630
# [7, 115000] loss: 1.624
# [7, 116000] loss: 1.622
# [7, 117000] loss: 1.648
# [7, 118000] loss: 1.633
# [7, 119000] loss: 1.613
# [7, 120000] loss: 1.596
# [7, 121000] loss: 1.589
# [7, 122000] loss: 1.646
# [7, 123000] loss: 1.606
# [7, 124000] loss: 1.600
# [7, 125000] loss: 1.593
# [8,  1000] loss: 1.607
# [8,  2000] loss: 1.641
# [8,  3000] loss: 1.591
# [8,  4000] loss: 1.587
# [8,  5000] loss: 1.607
# [8,  6000] loss: 1.608
# [8,  7000] loss: 1.596
# [8,  8000] loss: 1.615
# [8,  9000] loss: 1.580
# [8, 10000] loss: 1.597
# [8, 11000] loss: 1.612
# [8, 12000] loss: 1.622
# [8, 13000] loss: 1.640
# [8, 14000] loss: 1.621
# [8, 15000] loss: 1.586
# [8, 16000] loss: 1.584
# [8, 17000] loss: 1.615
# [8, 18000] loss: 1.653
# [8, 19000] loss: 1.611
# [8, 20000] loss: 1.606
# [8, 21000] loss: 1.609
# [8, 22000] loss: 1.625
# [8, 23000] loss: 1.615
# [8, 24000] loss: 1.630
# [8, 25000] loss: 1.601
# [8, 26000] loss: 1.605
# [8, 27000] loss: 1.604
# [8, 28000] loss: 1.602
# [8, 29000] loss: 1.587
# [8, 30000] loss: 1.614
# [8, 31000] loss: 1.581
# [8, 32000] loss: 1.639
# [8, 33000] loss: 1.606
# [8, 34000] loss: 1.633
# [8, 35000] loss: 1.569
# [8, 36000] loss: 1.576
# [8, 37000] loss: 1.629
# [8, 38000] loss: 1.600
# [8, 39000] loss: 1.631
# [8, 40000] loss: 1.614
# [8, 41000] loss: 1.604
# [8, 42000] loss: 1.624
# [8, 43000] loss: 1.610
# [8, 44000] loss: 1.613
# [8, 45000] loss: 1.611
# [8, 46000] loss: 1.582
# [8, 47000] loss: 1.610
# [8, 48000] loss: 1.595
# [8, 49000] loss: 1.635
# [8, 50000] loss: 1.601
# [8, 51000] loss: 1.607
# [8, 52000] loss: 1.595
# [8, 53000] loss: 1.615
# [8, 54000] loss: 1.597
# [8, 55000] loss: 1.599
# [8, 56000] loss: 1.583
# [8, 57000] loss: 1.614
# [8, 58000] loss: 1.601
# [8, 59000] loss: 1.627
# [8, 60000] loss: 1.596
# [8, 61000] loss: 1.632
# [8, 62000] loss: 1.615
# [8, 63000] loss: 1.616
# [8, 64000] loss: 1.596
# [8, 65000] loss: 1.586
# [8, 66000] loss: 1.619
# [8, 67000] loss: 1.612
# [8, 68000] loss: 1.601
# [8, 69000] loss: 1.585
# [8, 70000] loss: 1.622
# [8, 71000] loss: 1.613
# [8, 72000] loss: 1.611
# [8, 73000] loss: 1.619
# [8, 74000] loss: 1.619
# [8, 75000] loss: 1.623
# [8, 76000] loss: 1.616
# [8, 77000] loss: 1.609
# [8, 78000] loss: 1.576
# [8, 79000] loss: 1.624
# [8, 80000] loss: 1.632
# [8, 81000] loss: 1.613
# [8, 82000] loss: 1.621
# [8, 83000] loss: 1.581
# [8, 84000] loss: 1.589
# [8, 85000] loss: 1.631
# [8, 86000] loss: 1.615
# [8, 87000] loss: 1.636
# [8, 88000] loss: 1.580
# [8, 89000] loss: 1.579
# [8, 90000] loss: 1.595
# [8, 91000] loss: 1.619
# [8, 92000] loss: 1.611
# [8, 93000] loss: 1.610
# [8, 94000] loss: 1.588
# [8, 95000] loss: 1.600
# [8, 96000] loss: 1.597
# [8, 97000] loss: 1.588
# [8, 98000] loss: 1.620
# [8, 99000] loss: 1.611
# [8, 100000] loss: 1.622
# [8, 101000] loss: 1.607
# [8, 102000] loss: 1.602
# [8, 103000] loss: 1.609
# [8, 104000] loss: 1.625
# [8, 105000] loss: 1.568
# [8, 106000] loss: 1.590
# [8, 107000] loss: 1.590
# [8, 108000] loss: 1.599
# [8, 109000] loss: 1.613
# [8, 110000] loss: 1.581
# [8, 111000] loss: 1.637
# [8, 112000] loss: 1.627
# [8, 113000] loss: 1.577
# [8, 114000] loss: 1.605
# [8, 115000] loss: 1.616
# [8, 116000] loss: 1.607
# [8, 117000] loss: 1.596
# [8, 118000] loss: 1.589
# [8, 119000] loss: 1.627
# [8, 120000] loss: 1.605
# [8, 121000] loss: 1.631
# [8, 122000] loss: 1.637
# [8, 123000] loss: 1.632
# [8, 124000] loss: 1.586
# [8, 125000] loss: 1.623
# [9,  1000] loss: 1.631
# [9,  2000] loss: 1.599
# [9,  3000] loss: 1.632
# [9,  4000] loss: 1.596
# [9,  5000] loss: 1.609
# [9,  6000] loss: 1.604
# [9,  7000] loss: 1.595
# [9,  8000] loss: 1.598
# [9,  9000] loss: 1.609
# [9, 10000] loss: 1.600
# [9, 11000] loss: 1.615
# [9, 12000] loss: 1.618
# [9, 13000] loss: 1.597
# [9, 14000] loss: 1.608
# [9, 15000] loss: 1.591
# [9, 16000] loss: 1.620
# [9, 17000] loss: 1.611
# [9, 18000] loss: 1.592
# [9, 19000] loss: 1.590
# [9, 20000] loss: 1.611
# [9, 21000] loss: 1.603
# [9, 22000] loss: 1.619
# [9, 23000] loss: 1.601
# [9, 24000] loss: 1.615
# [9, 25000] loss: 1.614
# [9, 26000] loss: 1.594
# [9, 27000] loss: 1.619
# [9, 28000] loss: 1.600
# [9, 29000] loss: 1.587
# [9, 30000] loss: 1.620
# [9, 31000] loss: 1.601
# [9, 32000] loss: 1.599
# [9, 33000] loss: 1.574
# [9, 34000] loss: 1.628
# [9, 35000] loss: 1.588
# [9, 36000] loss: 1.592
# [9, 37000] loss: 1.595
# [9, 38000] loss: 1.612
# [9, 39000] loss: 1.617
# [9, 40000] loss: 1.608
# [9, 41000] loss: 1.619
# [9, 42000] loss: 1.590
# [9, 43000] loss: 1.606
# [9, 44000] loss: 1.589
# [9, 45000] loss: 1.575
# [9, 46000] loss: 1.578
# [9, 47000] loss: 1.597
# [9, 48000] loss: 1.588
# [9, 49000] loss: 1.600
# [9, 50000] loss: 1.602
# [9, 51000] loss: 1.609
# [9, 52000] loss: 1.580
# [9, 53000] loss: 1.598
# [9, 54000] loss: 1.576
# [9, 55000] loss: 1.608
# [9, 56000] loss: 1.566
# [9, 57000] loss: 1.604
# [9, 58000] loss: 1.612
# [9, 59000] loss: 1.605
# [9, 60000] loss: 1.626
# [9, 61000] loss: 1.610
# [9, 62000] loss: 1.622
# [9, 63000] loss: 1.567
# [9, 64000] loss: 1.604
# [9, 65000] loss: 1.584
# [9, 66000] loss: 1.585
# [9, 67000] loss: 1.585
# [9, 68000] loss: 1.604
# [9, 69000] loss: 1.605
# [9, 70000] loss: 1.598
# [9, 71000] loss: 1.606
# [9, 72000] loss: 1.607
# [9, 73000] loss: 1.620
# [9, 74000] loss: 1.604
# [9, 75000] loss: 1.590
# [9, 76000] loss: 1.578
# [9, 77000] loss: 1.591
# [9, 78000] loss: 1.598
# [9, 79000] loss: 1.611
# [9, 80000] loss: 1.582
# [9, 81000] loss: 1.607
# [9, 82000] loss: 1.601
# [9, 83000] loss: 1.591
# [9, 84000] loss: 1.584
# [9, 85000] loss: 1.620
# [9, 86000] loss: 1.613
# [9, 87000] loss: 1.602
# [9, 88000] loss: 1.577
# [9, 89000] loss: 1.611
# [9, 90000] loss: 1.592
# [9, 91000] loss: 1.604
# [9, 92000] loss: 1.578
# [9, 93000] loss: 1.607
# [9, 94000] loss: 1.608
# [9, 95000] loss: 1.618
# [9, 96000] loss: 1.596
# [9, 97000] loss: 1.572
# [9, 98000] loss: 1.575
# [9, 99000] loss: 1.631
# [9, 100000] loss: 1.605
# [9, 101000] loss: 1.623
# [9, 102000] loss: 1.601
# [9, 103000] loss: 1.617
# [9, 104000] loss: 1.597
# [9, 105000] loss: 1.612
# [9, 106000] loss: 1.588
# [9, 107000] loss: 1.603
# [9, 108000] loss: 1.605
# [9, 109000] loss: 1.584
# [9, 110000] loss: 1.630
# [9, 111000] loss: 1.603
# [9, 112000] loss: 1.600
# [9, 113000] loss: 1.598
# [9, 114000] loss: 1.582
# [9, 115000] loss: 1.600
# [9, 116000] loss: 1.571
# [9, 117000] loss: 1.611
# [9, 118000] loss: 1.589
# [9, 119000] loss: 1.635
# [9, 120000] loss: 1.632
# [9, 121000] loss: 1.606
# [9, 122000] loss: 1.618
# [9, 123000] loss: 1.610
# [9, 124000] loss: 1.596
# [9, 125000] loss: 1.625
# [10,  1000] loss: 1.640
# [10,  2000] loss: 1.570
# [10,  3000] loss: 1.613
# [10,  4000] loss: 1.602
# [10,  5000] loss: 1.599
# [10,  6000] loss: 1.629
# [10,  7000] loss: 1.613
# [10,  8000] loss: 1.593
# [10,  9000] loss: 1.606
# [10, 10000] loss: 1.615
# [10, 11000] loss: 1.601
# [10, 12000] loss: 1.606
# [10, 13000] loss: 1.581
# [10, 14000] loss: 1.611
# [10, 15000] loss: 1.608
# [10, 16000] loss: 1.614
# [10, 17000] loss: 1.612
# [10, 18000] loss: 1.635
# [10, 19000] loss: 1.607
# [10, 20000] loss: 1.601
# [10, 21000] loss: 1.609
# [10, 22000] loss: 1.585
# [10, 23000] loss: 1.623
# [10, 24000] loss: 1.583
# [10, 25000] loss: 1.577
# [10, 26000] loss: 1.586
# [10, 27000] loss: 1.575
# [10, 28000] loss: 1.563
# [10, 29000] loss: 1.598
# [10, 30000] loss: 1.596
# [10, 31000] loss: 1.608
# [10, 32000] loss: 1.600
# [10, 33000] loss: 1.618
# [10, 34000] loss: 1.621
# [10, 35000] loss: 1.593
# [10, 36000] loss: 1.612
# [10, 37000] loss: 1.561
# [10, 38000] loss: 1.579
# [10, 39000] loss: 1.592
# [10, 40000] loss: 1.619
# [10, 41000] loss: 1.576
# [10, 42000] loss: 1.616
# [10, 43000] loss: 1.590
# [10, 44000] loss: 1.582
# [10, 45000] loss: 1.586
# [10, 46000] loss: 1.615
# [10, 47000] loss: 1.575
# [10, 48000] loss: 1.610
# [10, 49000] loss: 1.580
# [10, 50000] loss: 1.608
# [10, 51000] loss: 1.588
# [10, 52000] loss: 1.616
# [10, 53000] loss: 1.600
# [10, 54000] loss: 1.604
# [10, 55000] loss: 1.609
# [10, 56000] loss: 1.604
# [10, 57000] loss: 1.607
# [10, 58000] loss: 1.582
# [10, 59000] loss: 1.590
# [10, 60000] loss: 1.609
# [10, 61000] loss: 1.609
# [10, 62000] loss: 1.569
# [10, 63000] loss: 1.596
# [10, 64000] loss: 1.569
# [10, 65000] loss: 1.625
# [10, 66000] loss: 1.585
# [10, 67000] loss: 1.575
# [10, 68000] loss: 1.589
# [10, 69000] loss: 1.609
# [10, 70000] loss: 1.594
# [10, 71000] loss: 1.593
# [10, 72000] loss: 1.611
# [10, 73000] loss: 1.614
# [10, 74000] loss: 1.597
# [10, 75000] loss: 1.579
# [10, 76000] loss: 1.609
# [10, 77000] loss: 1.572
# [10, 78000] loss: 1.615
# [10, 79000] loss: 1.586
# [10, 80000] loss: 1.586
# [10, 81000] loss: 1.605
# [10, 82000] loss: 1.586
# [10, 83000] loss: 1.580
# [10, 84000] loss: 1.607
# [10, 85000] loss: 1.574
# [10, 86000] loss: 1.593
# [10, 87000] loss: 1.583
# [10, 88000] loss: 1.583
# [10, 89000] loss: 1.604
# [10, 90000] loss: 1.604
# [10, 91000] loss: 1.622
# [10, 92000] loss: 1.587
# [10, 93000] loss: 1.591
# [10, 94000] loss: 1.597
# [10, 95000] loss: 1.594
# [10, 96000] loss: 1.585
# [10, 97000] loss: 1.621
# [10, 98000] loss: 1.607
# [10, 99000] loss: 1.589
# [10, 100000] loss: 1.613
# [10, 101000] loss: 1.623
# [10, 102000] loss: 1.569
# [10, 103000] loss: 1.600
# [10, 104000] loss: 1.574
# [10, 105000] loss: 1.613
# [10, 106000] loss: 1.576
# [10, 107000] loss: 1.580
# [10, 108000] loss: 1.596
# [10, 109000] loss: 1.623
# [10, 110000] loss: 1.635
# [10, 111000] loss: 1.601
# [10, 112000] loss: 1.614
# [10, 113000] loss: 1.572
# [10, 114000] loss: 1.588
# [10, 115000] loss: 1.586
# [10, 116000] loss: 1.589
# [10, 117000] loss: 1.583
# [10, 118000] loss: 1.588
# [10, 119000] loss: 1.596
# [10, 120000] loss: 1.579
# [10, 121000] loss: 1.606
# [10, 122000] loss: 1.592
# [10, 123000] loss: 1.620
# [10, 124000] loss: 1.603
# [10, 125000] loss: 1.576
# Finished training, look below for time:
# 5139.50514292717

# %%
net
# Out:
# CNNFMnist(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 5, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(5, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
# Save the nueral net for the last part
import copy
netCopy = copy.deepcopy(net)
tme_copy = total_time_gpu_3_1
netCopy
# Out:
# CNNFMnist(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 5, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(5, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
trainset, testset,trainloader,testloader = load_Fashion_Data()

# %%
transfered_net = CNNFMnist2(net)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(transfered_net.parameters(), lr=0.001, momentum=0.9)
print(transfered_net)
# Out:
# CNNFMnist2(
#   (trained_cnnfmnist_model): CNNFMnist(
#     (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#     (conv2): Conv2d(10, 5, kernel_size=(3, 3), stride=(1, 1))
#     (conv3): Conv2d(5, 16, kernel_size=(3, 3), stride=(1, 1))
#     (fc1): Linear(in_features=256, out_features=128, bias=True)
#     (fc2): Linear(in_features=128, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=10, bias=True)
#   )
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=10, bias=True)
# )

# %%
start = time.time()
train_loss_gpu_3_1, test_loss_gpu_3_1 = train_and_test_nn(epoch_number=10,show_loss_round=1000, GPU=True)
end = time.time()
total_time_gpu_3_1 += end - start
print(total_time_gpu_3_1)
# Out:
# [1,  1000] loss: 1.059
# [1,  2000] loss: 0.700
# [1,  3000] loss: 0.619
# [1,  4000] loss: 0.554
# [1,  5000] loss: 0.561
# [1,  6000] loss: 0.531
# [1,  7000] loss: 0.492
# [1,  8000] loss: 0.466
# [1,  9000] loss: 0.449
# [1, 10000] loss: 0.464
# [1, 11000] loss: 0.455
# [1, 12000] loss: 0.453
# [1, 13000] loss: 0.456
# [1, 14000] loss: 0.403
# [1, 15000] loss: 0.430
# [2,  1000] loss: 0.375
# [2,  2000] loss: 0.410
# [2,  3000] loss: 0.394
# [2,  4000] loss: 0.398
# [2,  5000] loss: 0.383
# [2,  6000] loss: 0.390
# [2,  7000] loss: 0.381
# [2,  8000] loss: 0.412
# [2,  9000] loss: 0.416
# [2, 10000] loss: 0.390
# [2, 11000] loss: 0.374
# [2, 12000] loss: 0.381
# [2, 13000] loss: 0.396
# [2, 14000] loss: 0.376
# [2, 15000] loss: 0.362
# [3,  1000] loss: 0.343
# [3,  2000] loss: 0.345
# [3,  3000] loss: 0.340
# [3,  4000] loss: 0.355
# [3,  5000] loss: 0.363
# [3,  6000] loss: 0.365
# [3,  7000] loss: 0.350
# [3,  8000] loss: 0.357
# [3,  9000] loss: 0.347
# [3, 10000] loss: 0.353
# [3, 11000] loss: 0.335
# [3, 12000] loss: 0.358
# [3, 13000] loss: 0.356
# [3, 14000] loss: 0.355
# [3, 15000] loss: 0.350
# [4,  1000] loss: 0.322
# [4,  2000] loss: 0.319
# [4,  3000] loss: 0.313
# [4,  4000] loss: 0.335
# [4,  5000] loss: 0.350
# [4,  6000] loss: 0.332
# [4,  7000] loss: 0.336
# [4,  8000] loss: 0.324
# [4,  9000] loss: 0.346
# [4, 10000] loss: 0.328
# [4, 11000] loss: 0.314
# [4, 12000] loss: 0.327
# [4, 13000] loss: 0.342
# [4, 14000] loss: 0.318
# [4, 15000] loss: 0.328
# [5,  1000] loss: 0.312
# [5,  2000] loss: 0.328
# [5,  3000] loss: 0.320
# [5,  4000] loss: 0.326
# [5,  5000] loss: 0.300
# [5,  6000] loss: 0.307
# [5,  7000] loss: 0.331
# [5,  8000] loss: 0.306
# [5,  9000] loss: 0.291
# [5, 10000] loss: 0.331
# [5, 11000] loss: 0.319
# [5, 12000] loss: 0.302
# [5, 13000] loss: 0.323
# [5, 14000] loss: 0.283
# [5, 15000] loss: 0.320
# [6,  1000] loss: 0.304
# [6,  2000] loss: 0.312
# [6,  3000] loss: 0.309
# [6,  4000] loss: 0.289
# [6,  5000] loss: 0.305
# [6,  6000] loss: 0.308
# [6,  7000] loss: 0.281
# [6,  8000] loss: 0.293
# [6,  9000] loss: 0.303
# [6, 10000] loss: 0.313
# [6, 11000] loss: 0.307
# [6, 12000] loss: 0.291
# [6, 13000] loss: 0.289
# [6, 14000] loss: 0.293
# [6, 15000] loss: 0.298
# [7,  1000] loss: 0.291
# [7,  2000] loss: 0.295
# [7,  3000] loss: 0.266
# [7,  4000] loss: 0.306
# [7,  5000] loss: 0.298
# [7,  6000] loss: 0.302
# [7,  7000] loss: 0.284
# [7,  8000] loss: 0.285
# [7,  9000] loss: 0.315
# [7, 10000] loss: 0.275
# [7, 11000] loss: 0.280
# [7, 12000] loss: 0.286
# [7, 13000] loss: 0.293
# [7, 14000] loss: 0.296
# [7, 15000] loss: 0.289
# [8,  1000] loss: 0.272
# [8,  2000] loss: 0.268
# [8,  3000] loss: 0.274
# [8,  4000] loss: 0.261
# [8,  5000] loss: 0.273
# [8,  6000] loss: 0.301
# [8,  7000] loss: 0.278
# [8,  8000] loss: 0.281
# [8,  9000] loss: 0.289
# [8, 10000] loss: 0.269
# [8, 11000] loss: 0.291
# [8, 12000] loss: 0.310
# [8, 13000] loss: 0.289
# [8, 14000] loss: 0.287
# [8, 15000] loss: 0.288
# [9,  1000] loss: 0.279
# [9,  2000] loss: 0.282
# [9,  3000] loss: 0.256
# [9,  4000] loss: 0.288
# [9,  5000] loss: 0.286
# [9,  6000] loss: 0.261
# [9,  7000] loss: 0.256
# [9,  8000] loss: 0.275
# [9,  9000] loss: 0.264
# [9, 10000] loss: 0.277
# [9, 11000] loss: 0.273
# [9, 12000] loss: 0.287
# [9, 13000] loss: 0.281
# [9, 14000] loss: 0.270
# [9, 15000] loss: 0.274
# [10,  1000] loss: 0.278
# [10,  2000] loss: 0.269
# [10,  3000] loss: 0.268
# [10,  4000] loss: 0.256
# [10,  5000] loss: 0.263
# [10,  6000] loss: 0.266
# [10,  7000] loss: 0.274
# [10,  8000] loss: 0.273
# [10,  9000] loss: 0.269
# [10, 10000] loss: 0.230
# [10, 11000] loss: 0.287
# [10, 12000] loss: 0.276
# [10, 13000] loss: 0.248
# [10, 14000] loss: 0.246
# [10, 15000] loss: 0.263
# Finished training, look below for time:
# 5635.07404589653

# %%
accu_gpu_3_1 = compute_accuracy(GPU=True)
accu_gpu_3_1
# Out:
# Accuracy of the network on the test images: 88 %
# 88.27

# %% [markdown]
# ##### 3.2 Untrained Net

# %%
net = CNNFMnist().cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
print(net)
# Out:
# CNNFMnist(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 5, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(5, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
start = time.time()
train_loss_gpu_3_2, test_loss_gpu_3_2 = train_and_test_nn(epoch_number=10,show_loss_round=1000, GPU=True)
end = time.time()
total_time_gpu_3_2 = end - start
print(total_time_gpu_3_2)
# Out:
# [1,  1000] loss: 2.301
# [1,  2000] loss: 2.096
# [1,  3000] loss: 1.000
# [1,  4000] loss: 0.824
# [1,  5000] loss: 0.759
# [1,  6000] loss: 0.718
# [1,  7000] loss: 0.681
# [1,  8000] loss: 0.654
# [1,  9000] loss: 0.629
# [1, 10000] loss: 0.619
# [1, 11000] loss: 0.611
# [1, 12000] loss: 0.561
# [1, 13000] loss: 0.537
# [1, 14000] loss: 0.532
# [1, 15000] loss: 0.498
# [2,  1000] loss: 0.497
# [2,  2000] loss: 0.516
# [2,  3000] loss: 0.498
# [2,  4000] loss: 0.481
# [2,  5000] loss: 0.474
# [2,  6000] loss: 0.458
# [2,  7000] loss: 0.469
# [2,  8000] loss: 0.437
# [2,  9000] loss: 0.434
# [2, 10000] loss: 0.419
# [2, 11000] loss: 0.448
# [2, 12000] loss: 0.400
# [2, 13000] loss: 0.432
# [2, 14000] loss: 0.394
# [2, 15000] loss: 0.403
# [3,  1000] loss: 0.381
# [3,  2000] loss: 0.384
# [3,  3000] loss: 0.388
# [3,  4000] loss: 0.380
# [3,  5000] loss: 0.391
# [3,  6000] loss: 0.401
# [3,  7000] loss: 0.356
# [3,  8000] loss: 0.383
# [3,  9000] loss: 0.372
# [3, 10000] loss: 0.362
# [3, 11000] loss: 0.373
# [3, 12000] loss: 0.364
# [3, 13000] loss: 0.371
# [3, 14000] loss: 0.372
# [3, 15000] loss: 0.368
# [4,  1000] loss: 0.355
# [4,  2000] loss: 0.369
# [4,  3000] loss: 0.349
# [4,  4000] loss: 0.321
# [4,  5000] loss: 0.335
# [4,  6000] loss: 0.341
# [4,  7000] loss: 0.352
# [4,  8000] loss: 0.355
# [4,  9000] loss: 0.346
# [4, 10000] loss: 0.327
# [4, 11000] loss: 0.327
# [4, 12000] loss: 0.343
# [4, 13000] loss: 0.328
# [4, 14000] loss: 0.325
# [4, 15000] loss: 0.328
# [5,  1000] loss: 0.300
# [5,  2000] loss: 0.292
# [5,  3000] loss: 0.326
# [5,  4000] loss: 0.331
# [5,  5000] loss: 0.292
# [5,  6000] loss: 0.318
# [5,  7000] loss: 0.321
# [5,  8000] loss: 0.327
# [5,  9000] loss: 0.308
# [5, 10000] loss: 0.305
# [5, 11000] loss: 0.319
# [5, 12000] loss: 0.329
# [5, 13000] loss: 0.321
# [5, 14000] loss: 0.307
# [5, 15000] loss: 0.321
# [6,  1000] loss: 0.278
# [6,  2000] loss: 0.304
# [6,  3000] loss: 0.290
# [6,  4000] loss: 0.317
# [6,  5000] loss: 0.301
# [6,  6000] loss: 0.291
# [6,  7000] loss: 0.300
# [6,  8000] loss: 0.304
# [6,  9000] loss: 0.296
# [6, 10000] loss: 0.277
# [6, 11000] loss: 0.296
# [6, 12000] loss: 0.279
# [6, 13000] loss: 0.305
# [6, 14000] loss: 0.312
# [6, 15000] loss: 0.319
# [7,  1000] loss: 0.285
# [7,  2000] loss: 0.291
# [7,  3000] loss: 0.281
# [7,  4000] loss: 0.290
# [7,  5000] loss: 0.305
# [7,  6000] loss: 0.288
# [7,  7000] loss: 0.270
# [7,  8000] loss: 0.301
# [7,  9000] loss: 0.272
# [7, 10000] loss: 0.280
# [7, 11000] loss: 0.267
# [7, 12000] loss: 0.286
# [7, 13000] loss: 0.288
# [7, 14000] loss: 0.301
# [7, 15000] loss: 0.283
# [8,  1000] loss: 0.275
# [8,  2000] loss: 0.251
# [8,  3000] loss: 0.259
# [8,  4000] loss: 0.263
# [8,  5000] loss: 0.257
# [8,  6000] loss: 0.259
# [8,  7000] loss: 0.274
# [8,  8000] loss: 0.277
# [8,  9000] loss: 0.266
# [8, 10000] loss: 0.273
# [8, 11000] loss: 0.291
# [8, 12000] loss: 0.288
# [8, 13000] loss: 0.279
# [8, 14000] loss: 0.274
# [8, 15000] loss: 0.280
# [9,  1000] loss: 0.251
# [9,  2000] loss: 0.266
# [9,  3000] loss: 0.253
# [9,  4000] loss: 0.265
# [9,  5000] loss: 0.254
# [9,  6000] loss: 0.265
# [9,  7000] loss: 0.285
# [9,  8000] loss: 0.287
# [9,  9000] loss: 0.256
# [9, 10000] loss: 0.256
# [9, 11000] loss: 0.251
# [9, 12000] loss: 0.261
# [9, 13000] loss: 0.257
# [9, 14000] loss: 0.272
# [9, 15000] loss: 0.256
# [10,  1000] loss: 0.252
# [10,  2000] loss: 0.248
# [10,  3000] loss: 0.279
# [10,  4000] loss: 0.253
# [10,  5000] loss: 0.246
# [10,  6000] loss: 0.250
# [10,  7000] loss: 0.262
# [10,  8000] loss: 0.257
# [10,  9000] loss: 0.260
# [10, 10000] loss: 0.266
# [10, 11000] loss: 0.241
# [10, 12000] loss: 0.266
# [10, 13000] loss: 0.241
# [10, 14000] loss: 0.243
# [10, 15000] loss: 0.257
# Finished training, look below for time:
# 484.12505173683167

# %%
accu_gpu_3_2 = compute_accuracy(GPU=True)
accu_gpu_3_2
# Out:
# Accuracy of the network on the test images: 88 %
# 88.63

# %% [markdown]
# ##### 3.3 Pre-trained Net + Freezing

# %%
# Freezing the weights
netCopy.conv1.eval()
netCopy.conv2.eval()
netCopy.conv3.eval()
netCopy.fc1.eval()
netCopy.fc2.eval()
# Out:
# Linear(in_features=128, out_features=64, bias=True)

# %%
trainset, testset,trainloader,testloader = load_Fashion_Data()

# %%
start = time.time()
train_loss_gpu_3_3, test_loss_gpu_3_3 = train_and_test_nn(epoch_number=10,show_loss_round=1000, GPU=True)
end = time.time()
total_time_gpu_3_3 = tme_copy + end - start
print(total_time_gpu_3_3)
# Out:
# [1,  1000] loss: 0.241
# [1,  2000] loss: 0.261
# [1,  3000] loss: 0.279
# [1,  4000] loss: 0.270
# [1,  5000] loss: 0.252
# [1,  6000] loss: 0.263
# [1,  7000] loss: 0.254
# [1,  8000] loss: 0.254
# [1,  9000] loss: 0.258
# [1, 10000] loss: 0.257
# [1, 11000] loss: 0.250
# [1, 12000] loss: 0.268
# [1, 13000] loss: 0.247
# [1, 14000] loss: 0.258
# [1, 15000] loss: 0.266
# [2,  1000] loss: 0.238
# [2,  2000] loss: 0.246
# [2,  3000] loss: 0.257
# [2,  4000] loss: 0.253
# [2,  5000] loss: 0.262
# [2,  6000] loss: 0.264
# [2,  7000] loss: 0.276
# [2,  8000] loss: 0.249
# [2,  9000] loss: 0.243
# [2, 10000] loss: 0.258
# [2, 11000] loss: 0.243
# [2, 12000] loss: 0.263
# [2, 13000] loss: 0.259
# [2, 14000] loss: 0.247
# [2, 15000] loss: 0.227
# [3,  1000] loss: 0.229
# [3,  2000] loss: 0.251
# [3,  3000] loss: 0.239
# [3,  4000] loss: 0.228
# [3,  5000] loss: 0.246
# [3,  6000] loss: 0.251
# [3,  7000] loss: 0.244
# [3,  8000] loss: 0.243
# [3,  9000] loss: 0.252
# [3, 10000] loss: 0.253
# [3, 11000] loss: 0.254
# [3, 12000] loss: 0.252
# [3, 13000] loss: 0.259
# [3, 14000] loss: 0.250
# [3, 15000] loss: 0.274
# [4,  1000] loss: 0.232
# [4,  2000] loss: 0.241
# [4,  3000] loss: 0.236
# [4,  4000] loss: 0.231
# [4,  5000] loss: 0.241
# [4,  6000] loss: 0.238
# [4,  7000] loss: 0.244
# [4,  8000] loss: 0.243
# [4,  9000] loss: 0.225
# [4, 10000] loss: 0.233
# [4, 11000] loss: 0.252
# [4, 12000] loss: 0.248
# [4, 13000] loss: 0.258
# [4, 14000] loss: 0.245
# [4, 15000] loss: 0.270
# [5,  1000] loss: 0.210
# [5,  2000] loss: 0.232
# [5,  3000] loss: 0.231
# [5,  4000] loss: 0.247
# [5,  5000] loss: 0.224
# [5,  6000] loss: 0.230
# [5,  7000] loss: 0.224
# [5,  8000] loss: 0.238
# [5,  9000] loss: 0.248
# [5, 10000] loss: 0.236
# [5, 11000] loss: 0.242
# [5, 12000] loss: 0.259
# [5, 13000] loss: 0.236
# [5, 14000] loss: 0.248
# [5, 15000] loss: 0.247
# [6,  1000] loss: 0.214
# [6,  2000] loss: 0.212
# [6,  3000] loss: 0.223
# [6,  4000] loss: 0.218
# [6,  5000] loss: 0.251
# [6,  6000] loss: 0.223
# [6,  7000] loss: 0.226
# [6,  8000] loss: 0.245
# [6,  9000] loss: 0.222
# [6, 10000] loss: 0.223
# [6, 11000] loss: 0.256
# [6, 12000] loss: 0.238
# [6, 13000] loss: 0.236
# [6, 14000] loss: 0.244
# [6, 15000] loss: 0.262
# [7,  1000] loss: 0.223
# [7,  2000] loss: 0.216
# [7,  3000] loss: 0.227
# [7,  4000] loss: 0.220
# [7,  5000] loss: 0.203
# [7,  6000] loss: 0.239
# [7,  7000] loss: 0.247
# [7,  8000] loss: 0.226
# [7,  9000] loss: 0.220
# [7, 10000] loss: 0.249
# [7, 11000] loss: 0.232
# [7, 12000] loss: 0.229
# [7, 13000] loss: 0.212
# [7, 14000] loss: 0.248
# [7, 15000] loss: 0.229
# [8,  1000] loss: 0.219
# [8,  2000] loss: 0.209
# [8,  3000] loss: 0.218
# [8,  4000] loss: 0.227
# [8,  5000] loss: 0.235
# [8,  6000] loss: 0.213
# [8,  7000] loss: 0.230
# [8,  8000] loss: 0.213
# [8,  9000] loss: 0.236
# [8, 10000] loss: 0.235
# [8, 11000] loss: 0.222
# [8, 12000] loss: 0.217
# [8, 13000] loss: 0.216
# [8, 14000] loss: 0.230
# [8, 15000] loss: 0.236
# [9,  1000] loss: 0.206
# [9,  2000] loss: 0.202
# [9,  3000] loss: 0.225
# [9,  4000] loss: 0.227
# [9,  5000] loss: 0.210
# [9,  6000] loss: 0.233
# [9,  7000] loss: 0.232
# [9,  8000] loss: 0.219
# [9,  9000] loss: 0.226
# [9, 10000] loss: 0.219
# [9, 11000] loss: 0.203
# [9, 12000] loss: 0.235
# [9, 13000] loss: 0.222
# [9, 14000] loss: 0.224
# [9, 15000] loss: 0.229
# [10,  1000] loss: 0.210
# [10,  2000] loss: 0.200
# [10,  3000] loss: 0.223
# [10,  4000] loss: 0.221
# [10,  5000] loss: 0.215
# [10,  6000] loss: 0.223
# [10,  7000] loss: 0.217
# [10,  8000] loss: 0.208
# [10,  9000] loss: 0.207
# [10, 10000] loss: 0.221
# [10, 11000] loss: 0.204
# [10, 12000] loss: 0.234
# [10, 13000] loss: 0.240
# [10, 14000] loss: 0.229
# [10, 15000] loss: 0.216
# Finished training, look below for time:
# 5632.650177955627

# %%
accu_gpu_3_3 =  compute_accuracy(GPU=True)
accu_gpu_3_3
# Out:
# Accuracy of the network on the test images: 87 %
# 87.65

# %%
total_time_gpu_3_1,accu_gpu_3_1, total_time_gpu_3_2,accu_gpu_3_2, total_time_gpu_3_3,accu_gpu_3_3
# Out:
# (5635.07404589653, 88.27, 484.12505173683167, 88.63, 5632.650177955627, 87.65)

# %% [markdown]
# ### Showing the results in one graph:

# %%
fig, axes = plt.subplots(1, 2, figsize=(45.0, 18.0))
sns.barplot([3.1,3.2,3.3],[accu_gpu_3_1,accu_gpu_3_2,accu_gpu_3_3], ax=axes[0], orient="v",palette="rocket")
sns.barplot([3.1,3.2,3.3],[total_time_gpu_3_1,total_time_gpu_3_2,total_time_gpu_3_3], ax=axes[1], orient="v",palette="vlag")
axes[0].set_title("Accuracy")
axes[0].set_xlabel("Type of run")
axes[0].set_ylabel("Accuracy")
axes[1].set_title("Time")
axes[1].set_xlabel("Type of run")
axes[1].set_ylabel("Time")
plt.show()

# %% [markdown]
# # Submission instructions
#
# You should submit a pdf file with the following items:
#
# CPU Experiment:
# *   Plot of loss curves (train in blue, test in red)
# *   Training time
#
# GPU Experiment:
# *   Plot of loss curves (train in blue, test in red)
# *   Training time
#
# Transfer Learning Experiment:
# * Accuracy results on test set for the 2-3 implemeted settings (see above)
#
# Link for your collab notebook.
# ID and names of submitters.
#
#
# Good luck!
